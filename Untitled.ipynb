# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split

# %%
dataset=pd.read_csv("healthcare-dataset-stroke-data.csv")
dataset.drop("id",inplace=True,axis=1)
dataset.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %% [markdown]
# from sklearn.model_selection import train_test_split
# x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# !pip install dtale
# Out:
# Collecting dtale
#   Downloading dtale-1.44.1-py2.py3-none-any.whl (14.4 MB)
#      |████████████████████████████████| 14.4 MB 2.0 MB/s eta 0:00:01
# Collecting dash>=1.5.0
#   Downloading dash-1.20.0.tar.gz (77 kB)
#      |████████████████████████████████| 77 kB 4.3 MB/s  eta 0:00:01
# Collecting dash-colorscales
#   Downloading dash_colorscales-0.0.4.tar.gz (62 kB)
#      |████████████████████████████████| 62 kB 827 kB/s  eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Collecting strsimpy
#   Downloading strsimpy-0.2.0-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 1.7 MB/s eta 0:00:01
# Requirement already satisfied: scikit-learn in /home/vibhav/anaconda3/envs/healthcare/lib/python3.8/site-packages (from dtale) (0.24.2)
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Collecting itsdangerous
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: pandas in /home/vibhav/anaconda3/envs/healthcare/lib/python3.8/site-packages (from dtale) (1.2.4)
# Collecting networkx
#   Downloading networkx-2.5.1-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 9.4 MB/s eta 0:00:01
# Collecting openpyxl
#   Downloading openpyxl-3.0.7-py2.py3-none-any.whl (243 kB)
#      |████████████████████████████████| 243 kB 10.6 MB/s eta 0:00:01
# Collecting requests
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 5.7 MB/s  eta 0:00:01
# Requirement already satisfied: six in /home/vibhav/anaconda3/envs/healthcare/lib/python3.8/site-packages (from dtale) (1.15.0)
# Collecting ppscore
#   Downloading ppscore-1.2.0.tar.gz (47 kB)
#      |████████████████████████████████| 47 kB 3.1 MB/s  eta 0:00:01
# Collecting missingno
#   Downloading missingno-0.4.2-py3-none-any.whl (9.7 kB)
# Requirement already satisfied: scipy in /home/vibhav/anaconda3/envs/healthcare/lib/python3.8/site-packages (from dtale) (1.6.3)
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      |████████████████████████████████| 79.9 MB 1.8 MB/s eta 0:00:016
# Collecting dash-daq
#   Downloading dash_daq-0.5.0.tar.gz (642 kB)
#      |████████████████████████████████| 642 kB 7.4 MB/s eta 0:00:01
# Collecting seaborn
#   Downloading seaborn-0.11.1-py3-none-any.whl (285 kB)
#      |████████████████████████████████| 285 kB 10.2 MB/s eta 0:00:01
# Collecting Flask-Compress
#   Downloading Flask_Compress-1.9.0-py3-none-any.whl (7.3 kB)
# Collecting flask-ngrok
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Collecting dash-bootstrap-components
#   Downloading dash_bootstrap_components-0.12.0-py3-none-any.whl (191 kB)
#      |████████████████████████████████| 191 kB 9.2 MB/s eta 0:00:01
# Collecting future>=0.14.0
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 12.0 MB/s eta 0:00:01
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 4.2 MB/s  eta 0:00:01
# Collecting statsmodels
#   Downloading statsmodels-0.12.2-cp38-cp38-manylinux1_x86_64.whl (9.4 MB)
#      |████████████████████████████████| 9.4 MB 8.6 MB/s eta 0:00:01
# Collecting xarray
#   Downloading xarray-0.17.0-py3-none-any.whl (759 kB)
#      |████████████████████████████████| 759 kB 5.0 MB/s eta 0:00:01
# Collecting lz4
#   Downloading lz4-3.1.3-cp38-cp38-manylinux2010_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 5.0 MB/s eta 0:00:01
# Collecting plotly>=4.9.0
#   Downloading plotly-4.14.3-py2.py3-none-any.whl (13.2 MB)
#      |████████████████████████████████| 13.2 MB 3.2 MB/s eta 0:00:01
# Collecting Flask>=1.0
#   Downloading Flask-1.1.2-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 2.2 MB/s  eta 0:00:01
# Collecting dash_renderer==1.9.1
#   Downloading dash_renderer-1.9.1.tar.gz (1.0 MB)
#      |████████████████████████████████| 1.0 MB 6.7 MB/s eta 0:00:01
# Collecting dash-core-components==1.16.0
#   Downloading dash_core_components-1.16.0.tar.gz (3.5 MB)
#      |████████████████████████████████| 3.5 MB 2.1 MB/s eta 0:00:01
# Collecting dash-html-components==1.1.3
#   Downloading dash_html_components-1.1.3.tar.gz (82 kB)
#      |████████████████████████████████| 82 kB 619 kB/s  eta 0:00:01
# Collecting dash-table==4.11.3
#   Downloading dash_table-4.11.3.tar.gz (1.8 MB)
#      |████████████████████████████████| 1.8 MB 6.0 MB/s eta 0:00:01
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 965 kB/s eta 0:00:01
# Requirement already satisfied: Jinja2>=2.10.1 in /home/vibhav/anaconda3/envs/healthcare/lib/python3.8/site-packages (from Flask>=1.0->dtale) (2.11.3)
# Collecting Werkzeug>=0.15
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
#      |████████████████████████████████| 298 kB 8.9 MB/s eta 0:00:01
# Requirement already satisfied: MarkupSafe>=0.23 in /home/vibhav/anaconda3/envs/healthcare/lib/python3.8/site-packages (from Jinja2>=2.10.1->Flask>=1.0->dtale) (1.1.1)
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Collecting brotli
#   Downloading Brotli-1.0.9-cp38-cp38-manylinux1_x86_64.whl (357 kB)
#      |████████████████████████████████| 357 kB 9.7 MB/s eta 0:00:01
# Collecting matplotlib
#   Downloading matplotlib-3.4.1-cp38-cp38-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 1.5 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /home/vibhav/anaconda3/envs/healthcare/lib/python3.8/site-packages (from missingno->dtale) (1.20.2)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp38-cp38-manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 9.5 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.2.0-cp38-cp38-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 4.8 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /home/vibhav/anaconda3/envs/healthcare/lib/python3.8/site-packages (from matplotlib->missingno->dtale) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/vibhav/anaconda3/envs/healthcare/lib/python3.8/site-packages (from matplotlib->missingno->dtale) (2.8.1)
# Collecting decorator<5,>=4.3
#   Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Requirement already satisfied: pytz>=2017.3 in /home/vibhav/anaconda3/envs/healthcare/lib/python3.8/site-packages (from pandas->dtale) (2021.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/vibhav/anaconda3/envs/healthcare/lib/python3.8/site-packages (from scikit-learn->dtale) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /home/vibhav/anaconda3/envs/healthcare/lib/python3.8/site-packages (from scikit-learn->dtale) (1.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vibhav/anaconda3/envs/healthcare/lib/python3.8/site-packages (from requests->dtale) (2020.12.5)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.4-py2.py3-none-any.whl (153 kB)
#      |████████████████████████████████| 153 kB 7.6 MB/s eta 0:00:01
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 7.7 MB/s eta 0:00:01
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 4.2 MB/s  eta 0:00:01
# Collecting patsy>=0.5
#   Downloading patsy-0.5.1-py2.py3-none-any.whl (231 kB)
#      |████████████████████████████████| 231 kB 9.8 MB/s eta 0:00:01
# Requirement already satisfied: setuptools>=40.4 in /home/vibhav/anaconda3/envs/healthcare/lib/python3.8/site-packages (from xarray->dtale) (52.0.0.post20210125)
# Building wheels for collected packages: dash, dash-core-components, dash-html-components, dash-renderer, dash-table, future, retrying, dash-colorscales, dash-daq, ppscore
#   Building wheel for dash (setup.py) ... done
#   Created wheel for dash: filename=dash-1.20.0-py3-none-any.whl size=85831 sha256=f4a168598f6cf7c602b81a3d96e8978646bb4f8e92f93c10eb6201fea68b66c5
#   Stored in directory: /home/vibhav/.cache/pip/wheels/e3/1e/fa/0c810b67f082a7b9f33a128f6374b03cf5245edc45e37adbf8
#   Building wheel for dash-core-components (setup.py) ... done
#   Created wheel for dash-core-components: filename=dash_core_components-1.16.0-py3-none-any.whl size=3540991 sha256=3c04bf6b985c8e53116d0252cb3763a5b369dea3186da9711ad55321a19bfc06
#   Stored in directory: /home/vibhav/.cache/pip/wheels/68/92/0c/4ac6d91639a754ebf3adfab7172c61fe408e7c71d00b8cbf66
#   Building wheel for dash-html-components (setup.py) ... done
#   Created wheel for dash-html-components: filename=dash_html_components-1.1.3-py3-none-any.whl size=319471 sha256=e6c1138c0f73fb94b432caf8205ac3616a9e34c92de3503cdc1361d34fc8a44c
#   Stored in directory: /home/vibhav/.cache/pip/wheels/2a/a3/33/bf6842d5d279588f8989ee8c2f9d9d8feb7af82216493a1eea
#   Building wheel for dash-renderer (setup.py) ... done
#   Created wheel for dash-renderer: filename=dash_renderer-1.9.1-py3-none-any.whl size=1014878 sha256=118c350b411aad1ed53abdfc53a1b9ba50b7c28760929bfe181b3d39804bd9f3
#   Stored in directory: /home/vibhav/.cache/pip/wheels/ac/7e/fd/807844722d79d8babcd27b16e5f7ecc7b476c45ca607c11729
#   Building wheel for dash-table (setup.py) ... done
#   Created wheel for dash-table: filename=dash_table-4.11.3-py3-none-any.whl size=1827618 sha256=e283f4fdd1dcd214ac571b04b28ffa3afc94e5b1274cc05264ff5f170bc91749
#   Stored in directory: /home/vibhav/.cache/pip/wheels/0c/9c/bd/06904831bdaa998ad1f53584553c5e06324814328666699128
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=6c90ddb2e29e1581fe1a8e0978ee7fbb173013973d76fc0d6439c03878be8b34
#   Stored in directory: /home/vibhav/.cache/pip/wheels/8e/70/28/3d6ccd6e315f65f245da085482a2e1c7d14b90b30f239e2cf4
#   Building wheel for retrying (setup.py) ... done
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11429 sha256=6c6ee591abb378417c5fdf834b1d24b91c0436b8682dea58f92c47946aa80212
#   Stored in directory: /home/vibhav/.cache/pip/wheels/c4/a7/48/0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
#   Building wheel for dash-colorscales (setup.py) ... done
#   Created wheel for dash-colorscales: filename=dash_colorscales-0.0.4-py3-none-any.whl size=62598 sha256=788d6b23d81921d6196aa914a403ac9f83d9690fa66e61f410b179525fd6f659
#   Stored in directory: /home/vibhav/.cache/pip/wheels/fe/33/33/172dbfe1efc739352828854a113df599a428b58f68ed0c4f75
#   Building wheel for dash-daq (setup.py) ... done
#   Created wheel for dash-daq: filename=dash_daq-0.5.0-py3-none-any.whl size=669701 sha256=4f12dd10b389a1b2254f61f6f96c4664bc99ff7a74959ebc6e7f539fc21197b9
#   Stored in directory: /home/vibhav/.cache/pip/wheels/00/35/e5/57e90f10c529601c6627400513cb65dd5adb09752411f5a050
#   Building wheel for ppscore (setup.py) ... done
#   Created wheel for ppscore: filename=ppscore-1.2.0-py2.py3-none-any.whl size=13050 sha256=a0d9648d007d28e8e30179e185aff5fa7eef98b8d4152de982db294af5b955a0
#   Stored in directory: /home/vibhav/.cache/pip/wheels/fb/0e/65/da65ce669381fc01b6ef990d301d3586991f89bff1175877a4
# Successfully built dash dash-core-components dash-html-components dash-renderer dash-table future retrying dash-colorscales dash-daq ppscore
# Installing collected packages: Werkzeug, itsdangerous, click, retrying, pillow, kiwisolver, Flask, cycler, brotli, urllib3, plotly, matplotlib, idna, future, Flask-Compress, dash-table, dash-renderer, dash-html-components, dash-core-components, chardet, seaborn, requests, patsy, et-xmlfile, decorator, dash, xlrd, xarray, strsimpy, statsmodels, squarify, ppscore, openpyxl, networkx, missingno, lz4, kaleido, flask-ngrok, dash-daq, dash-colorscales, dash-bootstrap-components, dtale
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.0.7
#     Uninstalling decorator-5.0.7:
#       Successfully uninstalled decorator-5.0.7
# Successfully installed Flask-1.1.2 Flask-Compress-1.9.0 Werkzeug-1.0.1 brotli-1.0.9 chardet-4.0.0 click-7.1.2 cycler-0.10.0 dash-1.20.0 dash-bootstrap-components-0.12.0 dash-colorscales-0.0.4 dash-core-components-1.16.0 dash-daq-0.5.0 dash-html-components-1.1.3 dash-renderer-1.9.1 dash-table-4.11.3 decorator-4.4.2 dtale-1.44.1 et-xmlfile-1.1.0 flask-ngrok-0.0.25 future-0.18.2 idna-2.10 itsdangerous-1.1.0 kaleido-0.2.1 kiwisolver-1.3.1 lz4-3.1.3 matplotlib-3.4.1 missingno-0.4.2 networkx-2.5.1 openpyxl-3.0.7 patsy-0.5.1 pillow-8.2.0 plotly-4.14.3 ppscore-1.2.0 requests-2.25.1 retrying-1.3.3 seaborn-0.11.1 squarify-0.4.3 statsmodels-0.12.2 strsimpy-0.2.0 urllib3-1.26.4 xarray-0.17.0 xlrd-2.0.1

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             5110 non-null   object
#  1   age                5110 non-null   float64
#  2   hypertension       5110 non-null   int64
#  3   heart_disease      5110 non-null   int64
#  4   ever_married       5110 non-null   object
#  5   work_type          5110 non-null   object
#  6   Residence_type     5110 non-null   object
#  7   avg_glucose_level  5110 non-null   float64
#  8   bmi                4909 non-null   float64
#  9   smoking_status     5110 non-null   object
#  10  stroke             5110 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 439.3+ KB
